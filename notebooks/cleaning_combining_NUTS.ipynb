# %%
import pandas as pd
import numpy as np
import yaml

# %%
with open("../config.yaml", "r") as file:
    config = yaml.safe_load(file)

# %% [markdown]
# # Contamination dataframes

# %% [markdown]
# ## AIR

# %% [markdown]
# ### Air facilities > df1

# %%
df_air_releases_facilities = pd.read_csv(config['data']['raw']['file1'])
display(df_air_releases_facilities.head())
display(df_air_releases_facilities.dtypes)
# Out:
#   PublicationDate countryName  reportingYear  EPRTR_SectorCode  \
# 0      2026/02/13     Germany           2013               1.0
# 1      2026/02/13      Sweden           2020               7.0
# 2      2026/02/13     Romania           2013               5.0
# 3      2026/02/13       Italy           2021               7.0
# 4      2026/02/13     Czechia           2007               1.0
#
#                                  EPRTR_SectorName EPRTRAnnexIMainActivity  \
# 0                                   Energy sector                    1(e)
# 1  Intensive livestock production and aquaculture                 7(a)(i)
# 2                 Waste and wastewater management                    5(d)
# 3  Intensive livestock production and aquaculture                    7(a)
# 4                                   Energy sector                    1(c)
#
#                                    FacilityInspireId  \
# 0  https://registry.gdi-de.org/id/de.nw.inspire.p...
# 1                          SE.CAED/10017896.Facility
# 2                         RO.CAED/104TL0001.FACILITY
# 3                         IT.CAED/370602036.FACILITY
# 4                    CZ.MZP.U423/CZ14819275.FACILITY
#
#                        facilityName            city  Longitude   Latitude  \
# 0  RWE Power AG-Fabrik Fortuna Nord        Bergheim   6.658050  50.986950
# 1            Skåneägg Produktion AB          MÖRARP  12.849550  56.053160
# 2                      SC ECOREC SA          TULCEA  28.769671  45.190459
# 3                      RONCHETRIN 1  GAZZO VERONESE  11.106667  45.123611
# 4                        energetika           Štětí  14.380370  50.462296
#
#   addressConfidentialityReason TargetRelease             Pollutant  Releases  \
# 0                          NaN           AIR  Sulphur oxides (SOX)  824000.0
# 1                          NaN           AIR         Ammonia (NH3)   16300.0
# 2                          NaN           AIR         Methane (CH4)  269000.0
# 3                          NaN           AIR         Ammonia (NH3)   31920.0
# 4                          NaN           AIR  Sulphur oxides (SOX)  507000.0
#
#   confidentialityReason
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# PublicationDate                  object
# countryName                      object
# reportingYear                     int64
# EPRTR_SectorCode                float64
# EPRTR_SectorName                 object
# EPRTRAnnexIMainActivity          object
# FacilityInspireId                object
# facilityName                     object
# city                             object
# Longitude                       float64
# Latitude                        float64
# addressConfidentialityReason     object
# TargetRelease                    object
# Pollutant                        object
# Releases                        float64
# confidentialityReason            object
# dtype: object

# %%
df_air_releases_facilities.PublicationDate.unique()
# Out:
# array(['2026/02/13'], dtype=object)

# %%
df_air_releases_facilities = df_air_releases_facilities.drop(columns=['PublicationDate', 'EPRTR_SectorCode', 'EPRTRAnnexIMainActivity', 'FacilityInspireId', 'addressConfidentialityReason', 'confidentialityReason'])

# %%
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df1 = rename_columns(df_air_releases_facilities)

# %%
def df_info(df):
    print("\n    ----- Shape -----")
    print(df.shape)
    #print("\n    ---- df info ---")
    #print(df.info())
    print("\n    ---- Empty Values ---")
    print(df.isna().sum())
    print("\n    ----- Dtypes -----")
    print(df.dtypes)
    #print("\n    ---- Statistics ---")
    #return df.describe()
df_info(df1)
# Out:
#     ----- Shape -----
# (372206, 10)
#
#     ---- Empty Values ---
# countryname            0
# reportingyear          0
# eprtr_sectorname    4985
# facilityname           1
# city                 133
# longitude            806
# latitude             806
# targetrelease          0
# pollutant              0
# releases              78
# dtype: int64
#
#     ----- Dtypes -----
# countryname          object
# reportingyear         int64
# eprtr_sectorname     object
# facilityname         object
# city                 object
# longitude           float64
# latitude            float64
# targetrelease        object
# pollutant            object
# releases            float64
# dtype: object

# %%
df1.dropna(inplace=True)
print(df1.shape)
# Out:
# (366206, 10)

# %%
df1.head()
# Out:
#   countryname  reportingyear                                eprtr_sectorname  \
# 0     Germany           2013                                   Energy sector
# 1      Sweden           2020  Intensive livestock production and aquaculture
# 2     Romania           2013                 Waste and wastewater management
# 3       Italy           2021  Intensive livestock production and aquaculture
# 4     Czechia           2007                                   Energy sector
#
#                        facilityname            city  longitude   latitude  \
# 0  RWE Power AG-Fabrik Fortuna Nord        Bergheim   6.658050  50.986950
# 1            Skåneägg Produktion AB          MÖRARP  12.849550  56.053160
# 2                      SC ECOREC SA          TULCEA  28.769671  45.190459
# 3                      RONCHETRIN 1  GAZZO VERONESE  11.106667  45.123611
# 4                        energetika           Štětí  14.380370  50.462296
#
#   targetrelease             pollutant  releases
# 0           AIR  Sulphur oxides (SOX)  824000.0
# 1           AIR         Ammonia (NH3)   16300.0
# 2           AIR         Methane (CH4)  269000.0
# 3           AIR         Ammonia (NH3)   31920.0
# 4           AIR  Sulphur oxides (SOX)  507000.0

# %%
df1.isnull().sum()
# Out:
# countryname         0
# reportingyear       0
# eprtr_sectorname    0
# facilityname        0
# city                0
# longitude           0
# latitude            0
# targetrelease       0
# pollutant           0
# releases            0
# dtype: int64

# %% [markdown]
# ### Air releases national > df2

# %%
df_air_releases_national = pd.read_csv(config['data']['raw']['file3'])
display(df_air_releases_national.head())
display(df_air_releases_national.dtypes)
display(df_air_releases_national.shape)
# Out:
#   PublicationDate countryName  reportingYear  \
# 0      2026/02/13      France           2023
# 1      2026/02/13      Poland           2012
# 2      2026/02/13     Czechia           2013
# 3      2026/02/13    Portugal           2024
# 4      2026/02/13    Bulgaria           2009
#
#                                         Pollutant      Releases
# 0                             Tetrachloroethylene  1.108000e+04
# 1                                   Methane (CH4)  4.971020e+08
# 2                                   Methane (CH4)  1.865000e+06
# 3                              Pentachlorobenzene  1.070000e+00
# 4  Non-methane volatile organic compounds (NMVOC)  3.964000e+06
# PublicationDate     object
# countryName         object
# reportingYear        int64
# Pollutant           object
# Releases           float64
# dtype: object
# (13639, 5)

# %%
df_air_releases_national = df_air_releases_national.drop(columns=['PublicationDate'])
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df2 = rename_columns(df_air_releases_national)

df2.dropna(inplace=True)
print(df2.shape)
# Out:
# (13639, 4)

# %%
def df_info(df):
    print("\n    ----- Shape -----")
    print(df.shape)
    print("\n    ---- df info ---")
    print(df.info())
    print("\n    ---- Empty Values ---")
    print(df.isna().sum())
    print("\n    ----- Dtypes -----")
    print(df.dtypes)
    #print("\n    ---- Statistics ---")
    #return df.describe()
df_info(df2)
# Out:
#     ----- Shape -----
# (13639, 4)
#
#     ---- df info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13639 entries, 0 to 13638
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   countryname    13639 non-null  object
#  1   reportingyear  13639 non-null  int64
#  2   pollutant      13639 non-null  object
#  3   releases       13639 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 426.3+ KB
# None
#
#     ---- Empty Values ---
# countryname      0
# reportingyear    0
# pollutant        0
# releases         0
# dtype: int64
#
#     ----- Dtypes -----
# countryname       object
# reportingyear      int64
# pollutant         object
# releases         float64
# dtype: object

# %% [markdown]
# ### Air releases sector > df3

# %%
df_air_releases_sector = pd.read_csv(config['data']['raw']['file4'])
display(df_air_releases_sector.head())
display(df_air_releases_sector.dtypes)
display(df_air_releases_sector.shape)
# Out:
#   PublicationDate countryName  reportingYear  EPRTR_SectorCode  \
# 0      2026/02/13      Norway           2013               3.0
# 1      2026/02/13     Czechia           2014               1.0
# 2      2026/02/13       Italy           2008               1.0
# 3      2026/02/13       Spain           2018               1.0
# 4      2026/02/13      Serbia           2022               1.0
#
#    EPRTR_SectorName                      Pollutant      Releases
# 0  Mineral industry  Mercury and compounds (as Hg)  2.500000e+01
# 1     Energy sector  Arsenic and compounds (as As)  1.363400e+03
# 2     Energy sector          Nitrogen oxides (NOX)  1.039530e+08
# 3     Energy sector           Carbon dioxide (CO2)  7.229500e+10
# 4     Energy sector           Sulphur oxides (SOX)  3.087640e+08
# PublicationDate      object
# countryName          object
# reportingYear         int64
# EPRTR_SectorCode    float64
# EPRTR_SectorName     object
# Pollutant            object
# Releases            float64
# dtype: object
# (42000, 7)

# %%
df_air_releases_sector = df_air_releases_sector.drop(columns=['PublicationDate'])
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df3 = rename_columns(df_air_releases_national)

df3.dropna(inplace=True)
print(df3.shape)
# Out:
# (13639, 4)

# %%
def df_info(df):
    print("\n    ----- Shape -----")
    print(df.shape)
    print("\n    ---- df info ---")
    print(df.info())
    print("\n    ---- Empty Values ---")
    print(df.isna().sum())
    print("\n    ----- Dtypes -----")
    print(df.dtypes)
    #print("\n    ---- Statistics ---")
    #return df.describe()
df_info(df3)
# Out:
#     ----- Shape -----
# (13639, 4)
#
#     ---- df info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13639 entries, 0 to 13638
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   countryname    13639 non-null  object
#  1   reportingyear  13639 non-null  int64
#  2   pollutant      13639 non-null  object
#  3   releases       13639 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 426.3+ KB
# None
#
#     ---- Empty Values ---
# countryname      0
# reportingyear    0
# pollutant        0
# releases         0
# dtype: int64
#
#     ----- Dtypes -----
# countryname       object
# reportingyear      int64
# pollutant         object
# releases         float64
# dtype: object

# %% [markdown]
# ## WATER

# %% [markdown]
# ### Water facilities > df4

# %%
df_water_releases_facilities = pd.read_csv(config['data']['raw']['file2'])
display(df_water_releases_facilities.head())
display(df_water_releases_facilities.dtypes)
# Out:
# C:\Users\fotos\AppData\Local\Temp\ipykernel_10428\3054174240.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_water_releases_facilities = pd.read_csv(config['data']['raw']['file2'])
#   PublicationDate     countryName  reportingYear  EPRTR_SectorCode  \
# 0      2026/02/13  United Kingdom           2014               1.0
# 1      2026/02/13         Germany           2011               4.0
# 2      2026/02/13         Germany           2022               5.0
# 3      2026/02/13         Hungary           2007               5.0
# 4      2026/02/13        Portugal           2014               1.0
#
#                   EPRTR_SectorName EPRTRAnnexIMainActivity  \
# 0                    Energy sector                    1(c)
# 1                Chemical industry                4(b)(iv)
# 2  Waste and wastewater management                    5(f)
# 3  Waste and wastewater management                    5(f)
# 4                    Energy sector                    1(a)
#
#                                    FacilityInspireId  \
# 0           UK.CAED/BEISOffsh-Forties-Alpha.FACILITY
# 1  https://registry.gdi-de.org/id/de.nw.inspire.p...
# 2  https://registry.gdi-de.org/id/de.by.inspire.p...
# 3                         HU.OKIR/100609995.FACILITY
# 4                          PT.CAED/PT.APA05769662.CI
#
#                        facilityName               city  Longitude   Latitude  \
# 0                     Forties Alpha                 --   0.582170  57.435510
# 1                       Solvay GmbH          Rheinberg   6.577830  51.564710
# 2                      AmperVerband            Olching  11.360499  48.233805
# 3  Fővárosi Csatornázási Művek Zrt.  Budapest 04. ker.  19.073994  47.572780
# 4           Refinaria de Sines (CI)              SINES  -8.800138  37.963901
#
#   addressConfidentialityReason TargetRelease  \
# 0                          NaN         WATER
# 1                          NaN         WATER
# 2                          NaN         WATER
# 3                          NaN         WATER
# 4                          NaN         WATER
#
#                                          Pollutant  Releases  \
# 0                                       Anthracene     12.10
# 1                    Cadmium and compounds (as Cd)    113.00
# 2  Total organic carbon(as total C or COD/3) (TOC)  77700.00
# 3                    Mercury and compounds (as Hg)      5.05
# 4  Total organic carbon(as total C or COD/3) (TOC)  62100.00
#
#   confidentialityReason
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# PublicationDate                  object
# countryName                      object
# reportingYear                     int64
# EPRTR_SectorCode                float64
# EPRTR_SectorName                 object
# EPRTRAnnexIMainActivity          object
# FacilityInspireId                object
# facilityName                     object
# city                             object
# Longitude                       float64
# Latitude                        float64
# addressConfidentialityReason     object
# TargetRelease                    object
# Pollutant                        object
# Releases                        float64
# confidentialityReason            object
# dtype: object

# %%
df_water_releases_facilities = df_water_releases_facilities.drop(columns=['PublicationDate', 'EPRTR_SectorCode', 'EPRTRAnnexIMainActivity', 'FacilityInspireId', 'addressConfidentialityReason', 'confidentialityReason'])

# %%
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df4 = rename_columns(df_water_releases_facilities)

df4.dropna(inplace=True)
print(df4.shape)
# Out:
# (251384, 10)

# %%
def df_info(df):
    print("\n    ----- Shape -----")
    print(df.shape)
    print("\n    ---- df info ---")
    print(df.info())
    print("\n    ---- Empty Values ---")
    print(df.isna().sum())
    print("\n    ----- Dtypes -----")
    print(df.dtypes)
    #print("\n    ---- Statistics ---")
    #return df.describe()
df_info(df4)
# Out:
#     ----- Shape -----
# (251384, 10)
#
#     ---- df info ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 251384 entries, 0 to 254155
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   countryname       251384 non-null  object
#  1   reportingyear     251384 non-null  int64
#  2   eprtr_sectorname  251384 non-null  object
#  3   facilityname      251384 non-null  object
#  4   city              251384 non-null  object
#  5   longitude         251384 non-null  float64
#  6   latitude          251384 non-null  float64
#  7   targetrelease     251384 non-null  object
#  8   pollutant         251384 non-null  object
#  9   releases          251384 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 21.1+ MB
# None
#
#     ---- Empty Values ---
# countryname         0
# reportingyear       0
# eprtr_sectorname    0
# facilityname        0
# city                0
# longitude           0
# latitude            0
# targetrelease       0
# pollutant           0
# releases            0
# dtype: int64
#
#     ----- Dtypes -----
# countryname          object
# reportingyear         int64
# eprtr_sectorname     object
# facilityname         object
# city                 object
# longitude           float64
# latitude            float64
# targetrelease        object
# pollutant            object
# releases            float64
# dtype: object

# %%
df4.head()
# Out:
#       countryname  reportingyear                 eprtr_sectorname  \
# 0  United Kingdom           2014                    Energy sector
# 1         Germany           2011                Chemical industry
# 2         Germany           2022  Waste and wastewater management
# 3         Hungary           2007  Waste and wastewater management
# 4        Portugal           2014                    Energy sector
#
#                        facilityname               city  longitude   latitude  \
# 0                     Forties Alpha                 --   0.582170  57.435510
# 1                       Solvay GmbH          Rheinberg   6.577830  51.564710
# 2                      AmperVerband            Olching  11.360499  48.233805
# 3  Fővárosi Csatornázási Művek Zrt.  Budapest 04. ker.  19.073994  47.572780
# 4           Refinaria de Sines (CI)              SINES  -8.800138  37.963901
#
#   targetrelease                                        pollutant  releases
# 0         WATER                                       Anthracene     12.10
# 1         WATER                    Cadmium and compounds (as Cd)    113.00
# 2         WATER  Total organic carbon(as total C or COD/3) (TOC)  77700.00
# 3         WATER                    Mercury and compounds (as Hg)      5.05
# 4         WATER  Total organic carbon(as total C or COD/3) (TOC)  62100.00

# %%
df4.isnull().sum()
# Out:
# countryname         0
# reportingyear       0
# eprtr_sectorname    0
# facilityname        0
# city                0
# longitude           0
# latitude            0
# targetrelease       0
# pollutant           0
# releases            0
# dtype: int64

# %% [markdown]
# ### Water releases national > df5

# %%
df_water_releases_national = pd.read_csv(config['data']['raw']['file5'])
display(df_water_releases_national.head())
display(df_water_releases_national.dtypes)
display(df_water_releases_national.shape)
# Out:
#   PublicationDate countryName  reportingYear             Pollutant  \
# 0      2026/02/13       Italy           2019        Total nitrogen
# 1      2026/02/13     Belgium           2018          Fluoranthene
# 2      2026/02/13     Finland           2013  Phenols (as total C)
# 3      2026/02/13     Germany           2020           Isoproturon
# 4      2026/02/13     Germany           2010      Total phosphorus
#
#       Releases
# 0  24776324.60
# 1         3.08
# 2       544.20
# 3        30.80
# 4   1856310.00
# PublicationDate     object
# countryName         object
# reportingYear        int64
# Pollutant           object
# Releases           float64
# dtype: object
# (12607, 5)

# %%
df_water_releases_national = df_water_releases_national.drop(columns=['PublicationDate'])
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df5 = rename_columns(df_water_releases_national)

df5.dropna(inplace=True)
print(df5.shape)
# Out:
# (12607, 4)

# %%
def df_info(df):
    print("\n    ----- Shape -----")
    print(df.shape)
    print("\n    ---- df info ---")
    print(df.info())
    print("\n    ---- Empty Values ---")
    print(df.isna().sum())
    print("\n    ----- Dtypes -----")
    print(df.dtypes)
    #print("\n    ---- Statistics ---")
    #return df.describe()
df_info(df5)
# Out:
#     ----- Shape -----
# (12607, 4)
#
#     ---- df info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12607 entries, 0 to 12606
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   countryname    12607 non-null  object
#  1   reportingyear  12607 non-null  int64
#  2   pollutant      12607 non-null  object
#  3   releases       12607 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 394.1+ KB
# None
#
#     ---- Empty Values ---
# countryname      0
# reportingyear    0
# pollutant        0
# releases         0
# dtype: int64
#
#     ----- Dtypes -----
# countryname       object
# reportingyear      int64
# pollutant         object
# releases         float64
# dtype: object

# %% [markdown]
# ### Water releases sector > df6

# %%
df_water_releases_sector = pd.read_csv(config['data']['raw']['file6'])
display(df_water_releases_sector.head())
display(df_water_releases_sector.dtypes)
display(df_water_releases_sector.shape)
# Out:
#   PublicationDate  countryName  reportingYear  EPRTR_SectorCode  \
# 0      2026/02/13      Germany           2024               2.0
# 1      2026/02/13      Germany           2013               5.0
# 2      2026/02/13  Netherlands           2024               5.0
# 3      2026/02/13       Sweden           2016               6.0
# 4      2026/02/13        Italy           2007               6.0
#
#                            EPRTR_SectorName                       Pollutant  \
# 0       Production and processing of metals      Zinc and compounds (as Zn)
# 1           Waste and wastewater management                  Total nitrogen
# 2           Waste and wastewater management          Cyanides (as total CN)
# 3  Paper and wood production and processing                  Total nitrogen
# 4  Paper and wood production and processing  Chromium and compounds (as Cr)
#
#      Releases
# 0     11370.0
# 1  38222100.0
# 2       655.0
# 3   1728800.0
# 4       452.2
# PublicationDate      object
# countryName          object
# reportingYear         int64
# EPRTR_SectorCode    float64
# EPRTR_SectorName     object
# Pollutant            object
# Releases            float64
# dtype: object
# (33132, 7)

# %%
df_water_releases_sector = df_water_releases_sector.drop(columns=['PublicationDate'])
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df6 = rename_columns(df_water_releases_sector)

df6.dropna(inplace=True)
print(df6.shape)
# Out:
# (32227, 6)

# %%
def df_info(df):
    print("\n    ----- Shape -----")
    print(df.shape)
    print("\n    ---- df info ---")
    print(df.info())
    print("\n    ---- Empty Values ---")
    print(df.isna().sum())
    print("\n    ----- Dtypes -----")
    print(df.dtypes)
    #print("\n    ---- Statistics ---")
    #return df.describe()
df_info(df6)
# Out:
#     ----- Shape -----
# (32227, 6)
#
#     ---- df info ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 32227 entries, 0 to 33131
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   countryname       32227 non-null  object
#  1   reportingyear     32227 non-null  int64
#  2   eprtr_sectorcode  32227 non-null  float64
#  3   eprtr_sectorname  32227 non-null  object
#  4   pollutant         32227 non-null  object
#  5   releases          32227 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.7+ MB
# None
#
#     ---- Empty Values ---
# countryname         0
# reportingyear       0
# eprtr_sectorcode    0
# eprtr_sectorname    0
# pollutant           0
# releases            0
# dtype: int64
#
#     ----- Dtypes -----
# countryname          object
# reportingyear         int64
# eprtr_sectorcode    float64
# eprtr_sectorname     object
# pollutant            object
# releases            float64
# dtype: object

# %% [markdown]
# # NUTS - facilities df

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point

# %% [markdown]
# ## NUTS Water -> df1_NUTS

# %%
df1_NUTS = df1.dropna(subset=['longitude', 'latitude']).copy()

# %%
geometry = [Point(xy) for xy in zip(df1_NUTS['longitude'], df1_NUTS['latitude'])]
gdf_puntos = gpd.GeoDataFrame(df1_NUTS, geometry=geometry, crs="EPSG:4326")

# %%
url_nuts = "https://gisco-services.ec.europa.eu/distribution/v2/nuts/geojson/NUTS_RG_10M_2024_4326.geojson"
gdf_nuts = gpd.read_file(url_nuts)

# %%
gdf_nuts_2 = gdf_nuts[gdf_nuts['LEVL_CODE'] == 2]

# %%
df1_NUTS = gpd.sjoin(gdf_puntos, gdf_nuts_2, how="left", predicate="within")

# %%
df1_NUTS = pd.DataFrame(df1_NUTS).drop(columns=['geometry', 'index_right'])

# %%
df1_NUTS.head()
# Out:
#   countryname  reportingyear                                eprtr_sectorname  \
# 0     Germany           2013                                   Energy sector
# 1      Sweden           2020  Intensive livestock production and aquaculture
# 2     Romania           2013                 Waste and wastewater management
# 3       Italy           2021  Intensive livestock production and aquaculture
# 4     Czechia           2007                                   Energy sector
#
#                        facilityname            city  longitude   latitude  \
# 0  RWE Power AG-Fabrik Fortuna Nord        Bergheim   6.658050  50.986950
# 1            Skåneägg Produktion AB          MÖRARP  12.849550  56.053160
# 2                      SC ECOREC SA          TULCEA  28.769671  45.190459
# 3                      RONCHETRIN 1  GAZZO VERONESE  11.106667  45.123611
# 4                        energetika           Štětí  14.380370  50.462296
#
#   targetrelease             pollutant  releases  ... COAST_TYPE  NAME_ENGL  \
# 0           AIR  Sulphur oxides (SOX)  824000.0  ...        NaN    Germany
# 1           AIR         Ammonia (NH3)   16300.0  ...        NaN     Sweden
# 2           AIR         Methane (CH4)  269000.0  ...        NaN    Romania
# 3           AIR         Ammonia (NH3)   31920.0  ...        NaN      Italy
# 4           AIR  Sulphur oxides (SOX)  507000.0  ...        NaN    Czechia
#
#    NAME_FREN ISO3_CODE          SVRG_UN       CAPT  EU_STAT  EFTA_STAT  \
# 0  Allemagne       DEU  UN Member State     Berlin        T          F
# 1      Suède       SWE  UN Member State  Stockholm        T          F
# 2   Roumanie       ROU  UN Member State  Bucharest        T          F
# 3     Italie       ITA  UN Member State       Rome        T          F
# 4   Tchéquie       CZE  UN Member State     Prague        T          F
#
#   CC_STAT    NAME_GERM
# 0       F  Deutschland
# 1       F     Schweden
# 2       F     Rumänien
# 3       F      Italien
# 4       F   Tschechien
#
# [5 rows x 27 columns]

# %%
df1_NUTS.dtypes
# Out:
# countryname          object
# reportingyear         int64
# eprtr_sectorname     object
# facilityname         object
# city                 object
# longitude           float64
# latitude            float64
# targetrelease        object
# pollutant            object
# releases            float64
# NUTS_ID              object
# LEVL_CODE           float64
# CNTR_CODE            object
# NAME_LATN            object
# NUTS_NAME            object
# MOUNT_TYPE          float64
# URBN_TYPE           float64
# COAST_TYPE          float64
# NAME_ENGL            object
# NAME_FREN            object
# ISO3_CODE            object
# SVRG_UN              object
# CAPT                 object
# EU_STAT              object
# EFTA_STAT            object
# CC_STAT              object
# NAME_GERM            object
# dtype: object

# %%
df1_NUTS_clean = df1_NUTS.drop(columns=['NAME_LATN', 'NAME_ENGL', 'NAME_FREN', 'SVRG_UN', 'CAPT', 'EU_STAT', 'EU_STAT', 'CC_STAT', 'NAME_GERM', 'MOUNT_TYPE', 'URBN_TYPE', 'COAST_TYPE', 'EFTA_STAT', 'LEVL_CODE'])
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df1_NUTS_clean = rename_columns(df1_NUTS_clean)

# %%
df1_NUTS_clean['releases'] = df1_NUTS_clean['releases'].astype(int)
df1_NUTS_clean.head()
# Out:
#   countryname  reportingyear                                eprtr_sectorname  \
# 0     Germany           2013                                   Energy sector
# 1      Sweden           2020  Intensive livestock production and aquaculture
# 2     Romania           2013                 Waste and wastewater management
# 3       Italy           2021  Intensive livestock production and aquaculture
# 4     Czechia           2007                                   Energy sector
#
#                        facilityname            city  longitude   latitude  \
# 0  RWE Power AG-Fabrik Fortuna Nord        Bergheim   6.658050  50.986950
# 1            Skåneägg Produktion AB          MÖRARP  12.849550  56.053160
# 2                      SC ECOREC SA          TULCEA  28.769671  45.190459
# 3                      RONCHETRIN 1  GAZZO VERONESE  11.106667  45.123611
# 4                        energetika           Štětí  14.380370  50.462296
#
#   targetrelease             pollutant  releases nuts_id cntr_code  \
# 0           AIR  Sulphur oxides (SOX)    824000    DEA2        DE
# 1           AIR         Ammonia (NH3)     16300    SE22        SE
# 2           AIR         Methane (CH4)    269000    RO22        RO
# 3           AIR         Ammonia (NH3)     31920    ITH3        IT
# 4           AIR  Sulphur oxides (SOX)    507000    CZ04        CZ
#
#      nuts_name iso3_code
# 0         Köln       DEU
# 1   Sydsverige       SWE
# 2      Sud-Est       ROU
# 3       Veneto       ITA
# 4  Severozápad       CZE

# %% [markdown]
# ## NUTS Air -> df4_NUTS

# %%
df4_NUTS = df4.dropna(subset=['longitude', 'latitude']) . copy()

geometry = [Point(xy) for xy in zip(df4_NUTS['longitude' ], df4_NUTS['latitude' ])]
gdf_puntos = gpd.GeoDataFrame(df4_NUTS, geometry=geometry, crs="EPSG:4326")

url_nuts = "https://gisco-services.ec.europa.eu/distribution/v2/nuts/geojson/NUTS_RG_10M_2024_4326.geojson"
gdf_nuts = gpd.read_file(url_nuts)

gdf_nuts_2 = gdf_nuts[gdf_nuts['LEVL_CODE' ] == 2]

df4_NUTS = gpd.sjoin(gdf_puntos, gdf_nuts_2, how="left", predicate="within")

df4_NUTS = pd.DataFrame(df4_NUTS).drop(columns=['geometry', 'index_right'])

# %%
df4_NUTS_clean = df4_NUTS.drop(columns=['NAME_LATN', 'NAME_ENGL', 'NAME_FREN', 'SVRG_UN', 'CAPT', 'EU_STAT', 'EU_STAT', 'CC_STAT', 'NAME_GERM', 'MOUNT_TYPE', 'URBN_TYPE', 'COAST_TYPE', 'EFTA_STAT', 'LEVL_CODE'])
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df4_NUTS_clean = rename_columns(df4_NUTS_clean)

# %%
df4_NUTS_clean['releases'] = df4_NUTS_clean['releases'].astype(int)
df4_NUTS_clean.head()
# Out:
#       countryname  reportingyear                 eprtr_sectorname  \
# 0  United Kingdom           2014                    Energy sector
# 1         Germany           2011                Chemical industry
# 2         Germany           2022  Waste and wastewater management
# 3         Hungary           2007  Waste and wastewater management
# 4        Portugal           2014                    Energy sector
#
#                        facilityname               city  longitude   latitude  \
# 0                     Forties Alpha                 --   0.582170  57.435510
# 1                       Solvay GmbH          Rheinberg   6.577830  51.564710
# 2                      AmperVerband            Olching  11.360499  48.233805
# 3  Fővárosi Csatornázási Művek Zrt.  Budapest 04. ker.  19.073994  47.572780
# 4           Refinaria de Sines (CI)              SINES  -8.800138  37.963901
#
#   targetrelease                                        pollutant  releases  \
# 0         WATER                                       Anthracene        12
# 1         WATER                    Cadmium and compounds (as Cd)       113
# 2         WATER  Total organic carbon(as total C or COD/3) (TOC)     77700
# 3         WATER                    Mercury and compounds (as Hg)         5
# 4         WATER  Total organic carbon(as total C or COD/3) (TOC)     62100
#
#   nuts_id cntr_code   nuts_name iso3_code
# 0     NaN       NaN         NaN       NaN
# 1    DEA1        DE  Düsseldorf       DEU
# 2    DE21        DE  Oberbayern       DEU
# 3    HU11        HU    Budapest       HUN
# 4    PT1C        PT    Alentejo       PRT

# %%
df1_NUTS_clean.nuts_id.isna().value_counts()
# Out:
# nuts_id
# False    321861
# True      44345
# Name: count, dtype: int64

# %%
df4_NUTS_clean.dtypes
# Out:
# countryname          object
# reportingyear         int64
# eprtr_sectorname     object
# facilityname         object
# city                 object
# longitude           float64
# latitude            float64
# targetrelease        object
# pollutant            object
# releases              int64
# nuts_id              object
# cntr_code            object
# nuts_name            object
# iso3_code            object
# dtype: object

# %%
df1_NUTS_clean.dtypes
# Out:
# countryname          object
# reportingyear         int64
# eprtr_sectorname     object
# facilityname         object
# city                 object
# longitude           float64
# latitude            float64
# targetrelease        object
# pollutant            object
# releases              int64
# nuts_id              object
# cntr_code            object
# nuts_name            object
# iso3_code            object
# dtype: object

# %% [markdown]
#  ## To .csv

# %%
df1_NUTS_clean.to_csv('air_nuts_clean.csv', index=False, encoding='utf-8')

# %%
df4_NUTS_clean.to_csv('water_nuts_clean.csv', index=False, encoding='utf-8')
