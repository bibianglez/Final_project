# %%
import pandas as pd
import numpy as np
import yaml

# %%
with open("../config.yaml", "r") as file:
    config = yaml.safe_load(file)

# %% [markdown]
# # Contamination dataframes

# %% [markdown]
# ## AIR

# %% [markdown]
# ### Air facilities > df1

# %%
df_air_releases_facilities = pd.read_csv(config['data']['raw']['file1'])
display(df_air_releases_facilities.head())
display(df_air_releases_facilities.dtypes)
# Out:
#   PublicationDate countryName  reportingYear  EPRTR_SectorCode  \
# 0      2026/02/13     Germany           2013               1.0
# 1      2026/02/13      Sweden           2020               7.0
# 2      2026/02/13     Romania           2013               5.0
# 3      2026/02/13       Italy           2021               7.0
# 4      2026/02/13     Czechia           2007               1.0
#
#                                  EPRTR_SectorName EPRTRAnnexIMainActivity  \
# 0                                   Energy sector                    1(e)
# 1  Intensive livestock production and aquaculture                 7(a)(i)
# 2                 Waste and wastewater management                    5(d)
# 3  Intensive livestock production and aquaculture                    7(a)
# 4                                   Energy sector                    1(c)
#
#                                    FacilityInspireId  \
# 0  https://registry.gdi-de.org/id/de.nw.inspire.p...
# 1                          SE.CAED/10017896.Facility
# 2                         RO.CAED/104TL0001.FACILITY
# 3                         IT.CAED/370602036.FACILITY
# 4                    CZ.MZP.U423/CZ14819275.FACILITY
#
#                        facilityName            city  Longitude   Latitude  \
# 0  RWE Power AG-Fabrik Fortuna Nord        Bergheim   6.658050  50.986950
# 1            Skåneägg Produktion AB          MÖRARP  12.849550  56.053160
# 2                      SC ECOREC SA          TULCEA  28.769671  45.190459
# 3                      RONCHETRIN 1  GAZZO VERONESE  11.106667  45.123611
# 4                        energetika           Štětí  14.380370  50.462296
#
#   addressConfidentialityReason TargetRelease             Pollutant  Releases  \
# 0                          NaN           AIR  Sulphur oxides (SOX)  824000.0
# 1                          NaN           AIR         Ammonia (NH3)   16300.0
# 2                          NaN           AIR         Methane (CH4)  269000.0
# 3                          NaN           AIR         Ammonia (NH3)   31920.0
# 4                          NaN           AIR  Sulphur oxides (SOX)  507000.0
#
#   confidentialityReason
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# PublicationDate                  object
# countryName                      object
# reportingYear                     int64
# EPRTR_SectorCode                float64
# EPRTR_SectorName                 object
# EPRTRAnnexIMainActivity          object
# FacilityInspireId                object
# facilityName                     object
# city                             object
# Longitude                       float64
# Latitude                        float64
# addressConfidentialityReason     object
# TargetRelease                    object
# Pollutant                        object
# Releases                        float64
# confidentialityReason            object
# dtype: object

# %%
df_air_releases_facilities.PublicationDate.unique()
# Out:
# array(['2026/02/13'], dtype=object)

# %%
df_air_releases_facilities = df_air_releases_facilities.drop(columns=['PublicationDate'])

# %%
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df1 = rename_columns(df_air_releases_facilities)

# %%
def df_info(df):
    print("\n    ----- Shape -----")
    print(df.shape)
    #print("\n    ---- df info ---")
    #print(df.info())
    print("\n    ---- Empty Values ---")
    print(df.isna().sum())
    print("\n    ----- Dtypes -----")
    print(df.dtypes)
    #print("\n    ---- Statistics ---")
    #return df.describe()
df_info(df1)
# Out:
#     ----- Shape -----
# (372206, 15)
#
#     ---- Empty Values ---
# countryname                          0
# reportingyear                        0
# eprtr_sectorcode                  4985
# eprtr_sectorname                  4985
# eprtranneximainactivity           4985
# facilityinspireid                    0
# facilityname                         1
# city                               133
# longitude                          806
# latitude                           806
# addressconfidentialityreason    371400
# targetrelease                        0
# pollutant                            0
# releases                            78
# confidentialityreason           372128
# dtype: int64
#
#     ----- Dtypes -----
# countryname                      object
# reportingyear                     int64
# eprtr_sectorcode                float64
# eprtr_sectorname                 object
# eprtranneximainactivity          object
# facilityinspireid                object
# facilityname                     object
# city                             object
# longitude                       float64
# latitude                        float64
# addressconfidentialityreason     object
# targetrelease                    object
# pollutant                        object
# releases                        float64
# confidentialityreason            object
# dtype: object

# %%
df1.dropna(inplace=True)
print(df_air_releases_facilities.shape)
# Out:
# (0, 15)

# %% [markdown]
# ### Air releases national > df2

# %%
df_air_releases_national = pd.read_csv(config['data']['raw']['file3'])
display(df_air_releases_national.head())
display(df_air_releases_national.dtypes)
display(df_air_releases_national.shape)
# Out:
#   PublicationDate countryName  reportingYear  \
# 0      2026/02/13      France           2023
# 1      2026/02/13      Poland           2012
# 2      2026/02/13     Czechia           2013
# 3      2026/02/13    Portugal           2024
# 4      2026/02/13    Bulgaria           2009
#
#                                         Pollutant      Releases
# 0                             Tetrachloroethylene  1.108000e+04
# 1                                   Methane (CH4)  4.971020e+08
# 2                                   Methane (CH4)  1.865000e+06
# 3                              Pentachlorobenzene  1.070000e+00
# 4  Non-methane volatile organic compounds (NMVOC)  3.964000e+06
# PublicationDate     object
# countryName         object
# reportingYear        int64
# Pollutant           object
# Releases           float64
# dtype: object
# (13639, 5)

# %%
df_air_releases_national = df_air_releases_national.drop(columns=['PublicationDate'])
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df2 = rename_columns(df_air_releases_national)

df2.dropna(inplace=True)
print(df_air_releases_national.shape)
# Out:
# (13639, 4)

# %%
def df_info(df):
    print("\n    ----- Shape -----")
    print(df.shape)
    print("\n    ---- df info ---")
    print(df.info())
    print("\n    ---- Empty Values ---")
    print(df.isna().sum())
    print("\n    ----- Dtypes -----")
    print(df.dtypes)
    #print("\n    ---- Statistics ---")
    #return df.describe()
df_info(df2)
# Out:
#     ----- Shape -----
# (13639, 4)
#
#     ---- df info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13639 entries, 0 to 13638
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   countryname    13639 non-null  object
#  1   reportingyear  13639 non-null  int64
#  2   pollutant      13639 non-null  object
#  3   releases       13639 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 426.3+ KB
# None
#
#     ---- Empty Values ---
# countryname      0
# reportingyear    0
# pollutant        0
# releases         0
# dtype: int64
#
#     ----- Dtypes -----
# countryname       object
# reportingyear      int64
# pollutant         object
# releases         float64
# dtype: object

# %% [markdown]
# ### Air releases sector > df3

# %%
df_air_releases_sector = pd.read_csv(config['data']['raw']['file4'])
display(df_air_releases_sector.head())
display(df_air_releases_sector.dtypes)
display(df_air_releases_sector.shape)
# Out:
#   PublicationDate countryName  reportingYear  EPRTR_SectorCode  \
# 0      2026/02/13      Norway           2013               3.0
# 1      2026/02/13     Czechia           2014               1.0
# 2      2026/02/13       Italy           2008               1.0
# 3      2026/02/13       Spain           2018               1.0
# 4      2026/02/13      Serbia           2022               1.0
#
#    EPRTR_SectorName                      Pollutant      Releases
# 0  Mineral industry  Mercury and compounds (as Hg)  2.500000e+01
# 1     Energy sector  Arsenic and compounds (as As)  1.363400e+03
# 2     Energy sector          Nitrogen oxides (NOX)  1.039530e+08
# 3     Energy sector           Carbon dioxide (CO2)  7.229500e+10
# 4     Energy sector           Sulphur oxides (SOX)  3.087640e+08
# PublicationDate      object
# countryName          object
# reportingYear         int64
# EPRTR_SectorCode    float64
# EPRTR_SectorName     object
# Pollutant            object
# Releases            float64
# dtype: object
# (42000, 7)

# %%
df_air_releases_sector = df_air_releases_sector.drop(columns=['PublicationDate'])
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df3 = rename_columns(df_air_releases_national)

df3.dropna(inplace=True)
print(df3.shape)
# Out:
# (13639, 4)

# %%
def df_info(df):
    print("\n    ----- Shape -----")
    print(df.shape)
    print("\n    ---- df info ---")
    print(df.info())
    print("\n    ---- Empty Values ---")
    print(df.isna().sum())
    print("\n    ----- Dtypes -----")
    print(df.dtypes)
    #print("\n    ---- Statistics ---")
    #return df.describe()
df_info(df3)
# Out:
#     ----- Shape -----
# (13639, 4)
#
#     ---- df info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13639 entries, 0 to 13638
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   countryname    13639 non-null  object
#  1   reportingyear  13639 non-null  int64
#  2   pollutant      13639 non-null  object
#  3   releases       13639 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 426.3+ KB
# None
#
#     ---- Empty Values ---
# countryname      0
# reportingyear    0
# pollutant        0
# releases         0
# dtype: int64
#
#     ----- Dtypes -----
# countryname       object
# reportingyear      int64
# pollutant         object
# releases         float64
# dtype: object

# %% [markdown]
# ## WATER

# %% [markdown]
# ### Water facilities > df4

# %%
df_water_releases_facilities = pd.read_csv(config['data']['raw']['file2'])
display(df_water_releases_facilities.head())
display(df_water_releases_facilities.dtypes)
# Out:
# C:\Users\fotos\AppData\Local\Temp\ipykernel_17052\3054174240.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_water_releases_facilities = pd.read_csv(config['data']['raw']['file2'])
#   PublicationDate     countryName  reportingYear  EPRTR_SectorCode  \
# 0      2026/02/13  United Kingdom           2014               1.0
# 1      2026/02/13         Germany           2011               4.0
# 2      2026/02/13         Germany           2022               5.0
# 3      2026/02/13         Hungary           2007               5.0
# 4      2026/02/13        Portugal           2014               1.0
#
#                   EPRTR_SectorName EPRTRAnnexIMainActivity  \
# 0                    Energy sector                    1(c)
# 1                Chemical industry                4(b)(iv)
# 2  Waste and wastewater management                    5(f)
# 3  Waste and wastewater management                    5(f)
# 4                    Energy sector                    1(a)
#
#                                    FacilityInspireId  \
# 0           UK.CAED/BEISOffsh-Forties-Alpha.FACILITY
# 1  https://registry.gdi-de.org/id/de.nw.inspire.p...
# 2  https://registry.gdi-de.org/id/de.by.inspire.p...
# 3                         HU.OKIR/100609995.FACILITY
# 4                          PT.CAED/PT.APA05769662.CI
#
#                        facilityName               city  Longitude   Latitude  \
# 0                     Forties Alpha                 --   0.582170  57.435510
# 1                       Solvay GmbH          Rheinberg   6.577830  51.564710
# 2                      AmperVerband            Olching  11.360499  48.233805
# 3  Fővárosi Csatornázási Művek Zrt.  Budapest 04. ker.  19.073994  47.572780
# 4           Refinaria de Sines (CI)              SINES  -8.800138  37.963901
#
#   addressConfidentialityReason TargetRelease  \
# 0                          NaN         WATER
# 1                          NaN         WATER
# 2                          NaN         WATER
# 3                          NaN         WATER
# 4                          NaN         WATER
#
#                                          Pollutant  Releases  \
# 0                                       Anthracene     12.10
# 1                    Cadmium and compounds (as Cd)    113.00
# 2  Total organic carbon(as total C or COD/3) (TOC)  77700.00
# 3                    Mercury and compounds (as Hg)      5.05
# 4  Total organic carbon(as total C or COD/3) (TOC)  62100.00
#
#   confidentialityReason
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# PublicationDate                  object
# countryName                      object
# reportingYear                     int64
# EPRTR_SectorCode                float64
# EPRTR_SectorName                 object
# EPRTRAnnexIMainActivity          object
# FacilityInspireId                object
# facilityName                     object
# city                             object
# Longitude                       float64
# Latitude                        float64
# addressConfidentialityReason     object
# TargetRelease                    object
# Pollutant                        object
# Releases                        float64
# confidentialityReason            object
# dtype: object

# %%
df_water_releases_facilities = df_water_releases_facilities.drop(columns=['PublicationDate'])
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df4 = rename_columns(df_water_releases_facilities)

df4.dropna(inplace=True)
print(df4.shape)
# Out:
# (0, 15)

# %%
def df_info(df):
    print("\n    ----- Shape -----")
    print(df.shape)
    print("\n    ---- df info ---")
    print(df.info())
    print("\n    ---- Empty Values ---")
    print(df.isna().sum())
    print("\n    ----- Dtypes -----")
    print(df.dtypes)
    #print("\n    ---- Statistics ---")
    #return df.describe()
df_info(df4)
# Out:
#     ----- Shape -----
# (0, 15)
#
#     ---- df info ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   countryname                   0 non-null      object
#  1   reportingyear                 0 non-null      int64
#  2   eprtr_sectorcode              0 non-null      float64
#  3   eprtr_sectorname              0 non-null      object
#  4   eprtranneximainactivity       0 non-null      object
#  5   facilityinspireid             0 non-null      object
#  6   facilityname                  0 non-null      object
#  7   city                          0 non-null      object
#  8   longitude                     0 non-null      float64
#  9   latitude                      0 non-null      float64
#  10  addressconfidentialityreason  0 non-null      object
#  11  targetrelease                 0 non-null      object
#  12  pollutant                     0 non-null      object
#  13  releases                      0 non-null      float64
#  14  confidentialityreason         0 non-null      object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 0.0+ bytes
# None
#
#     ---- Empty Values ---
# countryname                     0
# reportingyear                   0
# eprtr_sectorcode                0
# eprtr_sectorname                0
# eprtranneximainactivity         0
# facilityinspireid               0
# facilityname                    0
# city                            0
# longitude                       0
# latitude                        0
# addressconfidentialityreason    0
# targetrelease                   0
# pollutant                       0
# releases                        0
# confidentialityreason           0
# dtype: int64
#
#     ----- Dtypes -----
# countryname                      object
# reportingyear                     int64
# eprtr_sectorcode                float64
# eprtr_sectorname                 object
# eprtranneximainactivity          object
# facilityinspireid                object
# facilityname                     object
# city                             object
# longitude                       float64
# latitude                        float64
# addressconfidentialityreason     object
# targetrelease                    object
# pollutant                        object
# releases                        float64
# confidentialityreason            object
# dtype: object

# %% [markdown]
# ### Water releases national > df5

# %%
df_water_releases_national = pd.read_csv(config['data']['raw']['file5'])
display(df_water_releases_national.head())
display(df_water_releases_national.dtypes)
display(df_water_releases_national.shape)
# Out:
#   PublicationDate countryName  reportingYear             Pollutant  \
# 0      2026/02/13       Italy           2019        Total nitrogen
# 1      2026/02/13     Belgium           2018          Fluoranthene
# 2      2026/02/13     Finland           2013  Phenols (as total C)
# 3      2026/02/13     Germany           2020           Isoproturon
# 4      2026/02/13     Germany           2010      Total phosphorus
#
#       Releases
# 0  24776324.60
# 1         3.08
# 2       544.20
# 3        30.80
# 4   1856310.00
# PublicationDate     object
# countryName         object
# reportingYear        int64
# Pollutant           object
# Releases           float64
# dtype: object
# (12607, 5)

# %%
df_water_releases_national = df_water_releases_national.drop(columns=['PublicationDate'])
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df5 = rename_columns(df_water_releases_national)

df5.dropna(inplace=True)
print(df5.shape)
# Out:
# (12607, 4)

# %%
def df_info(df):
    print("\n    ----- Shape -----")
    print(df.shape)
    print("\n    ---- df info ---")
    print(df.info())
    print("\n    ---- Empty Values ---")
    print(df.isna().sum())
    print("\n    ----- Dtypes -----")
    print(df.dtypes)
    #print("\n    ---- Statistics ---")
    #return df.describe()
df_info(df5)
# Out:
#     ----- Shape -----
# (12607, 4)
#
#     ---- df info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12607 entries, 0 to 12606
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   countryname    12607 non-null  object
#  1   reportingyear  12607 non-null  int64
#  2   pollutant      12607 non-null  object
#  3   releases       12607 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 394.1+ KB
# None
#
#     ---- Empty Values ---
# countryname      0
# reportingyear    0
# pollutant        0
# releases         0
# dtype: int64
#
#     ----- Dtypes -----
# countryname       object
# reportingyear      int64
# pollutant         object
# releases         float64
# dtype: object

# %% [markdown]
# ### Water releases sector > df6

# %%
df_water_releases_sector = pd.read_csv(config['data']['raw']['file6'])
display(df_water_releases_sector.head())
display(df_water_releases_sector.dtypes)
display(df_water_releases_sector.shape)
# Out:
#   PublicationDate  countryName  reportingYear  EPRTR_SectorCode  \
# 0      2026/02/13      Germany           2024               2.0
# 1      2026/02/13      Germany           2013               5.0
# 2      2026/02/13  Netherlands           2024               5.0
# 3      2026/02/13       Sweden           2016               6.0
# 4      2026/02/13        Italy           2007               6.0
#
#                            EPRTR_SectorName                       Pollutant  \
# 0       Production and processing of metals      Zinc and compounds (as Zn)
# 1           Waste and wastewater management                  Total nitrogen
# 2           Waste and wastewater management          Cyanides (as total CN)
# 3  Paper and wood production and processing                  Total nitrogen
# 4  Paper and wood production and processing  Chromium and compounds (as Cr)
#
#      Releases
# 0     11370.0
# 1  38222100.0
# 2       655.0
# 3   1728800.0
# 4       452.2
# PublicationDate      object
# countryName          object
# reportingYear         int64
# EPRTR_SectorCode    float64
# EPRTR_SectorName     object
# Pollutant            object
# Releases            float64
# dtype: object
# (33132, 7)

# %%
df_water_releases_sector = df_water_releases_sector.drop(columns=['PublicationDate'])
def rename_columns(df):
    df.rename(columns={col : col.strip() for col in df.columns}, inplace = True)
    df.rename(columns={col : col.replace(" ", "_").lower() for col in df.columns}, inplace = True)
    return df

df6 = rename_columns(df_water_releases_sector)

df6.dropna(inplace=True)
print(df6.shape)
# Out:
# (32227, 6)

# %%
def df_info(df):
    print("\n    ----- Shape -----")
    print(df.shape)
    print("\n    ---- df info ---")
    print(df.info())
    print("\n    ---- Empty Values ---")
    print(df.isna().sum())
    print("\n    ----- Dtypes -----")
    print(df.dtypes)
    #print("\n    ---- Statistics ---")
    #return df.describe()
df_info(df6)
# Out:
#     ----- Shape -----
# (32227, 6)
#
#     ---- df info ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 32227 entries, 0 to 33131
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   countryname       32227 non-null  object
#  1   reportingyear     32227 non-null  int64
#  2   eprtr_sectorcode  32227 non-null  float64
#  3   eprtr_sectorname  32227 non-null  object
#  4   pollutant         32227 non-null  object
#  5   releases          32227 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.7+ MB
# None
#
#     ---- Empty Values ---
# countryname         0
# reportingyear       0
# eprtr_sectorcode    0
# eprtr_sectorname    0
# pollutant           0
# releases            0
# dtype: int64
#
#     ----- Dtypes -----
# countryname          object
# reportingyear         int64
# eprtr_sectorcode    float64
# eprtr_sectorname     object
# pollutant            object
# releases            float64
# dtype: object

# %% [markdown]
# ## Air testing

# %%
df2.head()
# Out:
#   countryname  reportingyear                                       pollutant  \
# 0      France           2023                             Tetrachloroethylene
# 1      Poland           2012                                   Methane (CH4)
# 2     Czechia           2013                                   Methane (CH4)
# 3    Portugal           2024                              Pentachlorobenzene
# 4    Bulgaria           2009  Non-methane volatile organic compounds (NMVOC)
#
#        releases
# 0  1.108000e+04
# 1  4.971020e+08
# 2  1.865000e+06
# 3  1.070000e+00
# 4  3.964000e+06

# %%
pd_crosstab_df2 = pd.crosstab(index=df2['pollutant'], 
                              columns=df2['countryname'], 
                              values=df2['releases'], 
                              aggfunc='sum').round(0).fillna(0).astype(int)
pd_crosstab_df2
# Out:
# countryname                                         Austria  Belgium  \
# pollutant
# 1,1,1-trichloroethane (TCE-1,1,1)                         0     1011
# 1,1,2,2-tetrachloroethane (TETRACHLOROETHANE-1,...        0    16866
# 1,2,3,4,5,6-hexachlorocyclohexane (HCH)                   0        0
# 1,2-dichloroethane (DCE-1,2)                          34070   955800
# Aldrin                                                    0        0
# ...                                                     ...      ...
# Trichloroethylene (TRI)                                   0   101600
# Trichloromethane                                          0   295294
# Vinyl chloride                                            0   346870
# Xylenes                                                   0        0
# Zinc and compounds (as Zn)                           176307   655515
#
# countryname                                         Bulgaria  Croatia  Cyprus  \
# pollutant
# 1,1,1-trichloroethane (TCE-1,1,1)                          0        0       0
# 1,1,2,2-tetrachloroethane (TETRACHLOROETHANE-1,...         0        0       0
# 1,2,3,4,5,6-hexachlorocyclohexane (HCH)                    0        0       0
# 1,2-dichloroethane (DCE-1,2)                               0        0       0
# Aldrin                                                     0        0       0
# ...                                                      ...      ...     ...
# Trichloroethylene (TRI)                                    0        0       0
# Trichloromethane                                           0        0       0
# Vinyl chloride                                             0        0       0
# Xylenes                                                    0        0       0
# Zinc and compounds (as Zn)                            121682    25764   49602
#
# countryname                                         Czechia  Denmark  Estonia  \
# pollutant
# 1,1,1-trichloroethane (TCE-1,1,1)                         0        0        0
# 1,1,2,2-tetrachloroethane (TETRACHLOROETHANE-1,...        0        0        0
# 1,2,3,4,5,6-hexachlorocyclohexane (HCH)                   0        0        0
# 1,2-dichloroethane (DCE-1,2)                          27136        0        0
# Aldrin                                                    0        0        0
# ...                                                     ...      ...      ...
# Trichloroethylene (TRI)                              527216        0        0
# Trichloromethane                                          0        0        0
# Vinyl chloride                                        43113        0        0
# Xylenes                                                   0        0        0
# Zinc and compounds (as Zn)                           248600    13086   559974
#
# countryname                                         Finland   France  ...  \
# pollutant                                                             ...
# 1,1,1-trichloroethane (TCE-1,1,1)                         0   610720  ...
# 1,1,2,2-tetrachloroethane (TETRACHLOROETHANE-1,...        0     1470  ...
# 1,2,3,4,5,6-hexachlorocyclohexane (HCH)                   0        0  ...
# 1,2-dichloroethane (DCE-1,2)                              0  5961660  ...
# Aldrin                                                    0        0  ...
# ...                                                     ...      ...  ...
# Trichloroethylene (TRI)                               11600   809760  ...
# Trichloromethane                                          0  1116529  ...
# Vinyl chloride                                            0  4073470  ...
# Xylenes                                                   0        0  ...
# Zinc and compounds (as Zn)                           256824  1606100  ...
#
# countryname                                          Poland  Portugal  \
# pollutant
# 1,1,1-trichloroethane (TCE-1,1,1)                         0      5050
# 1,1,2,2-tetrachloroethane (TETRACHLOROETHANE-1,...     1003       194
# 1,2,3,4,5,6-hexachlorocyclohexane (HCH)                   0         0
# 1,2-dichloroethane (DCE-1,2)                         172210      2170
# Aldrin                                                 4010         0
# ...                                                     ...       ...
# Trichloroethylene (TRI)                               17610      3380
# Trichloromethane                                      32455    360050
# Vinyl chloride                                       296400     88090
# Xylenes                                                   0         0
# Zinc and compounds (as Zn)                          1540060    356490
#
# countryname                                         Romania  Serbia  Slovakia  \
# pollutant
# 1,1,1-trichloroethane (TCE-1,1,1)                         0       0         0
# 1,1,2,2-tetrachloroethane (TETRACHLOROETHANE-1,...        0       0         0
# 1,2,3,4,5,6-hexachlorocyclohexane (HCH)                   0      87         0
# 1,2-dichloroethane (DCE-1,2)                           4050       0    327680
# Aldrin                                                    0    1273         0
# ...                                                     ...     ...       ...
# Trichloroethylene (TRI)                                   0       0     25430
# Trichloromethane                                          0       0         0
# Vinyl chloride                                        63300       0    598000
# Xylenes                                                   0       0         0
# Zinc and compounds (as Zn)                           225534       0    108340
#
# countryname                                         Slovenia    Spain  Sweden  \
# pollutant
# 1,1,1-trichloroethane (TCE-1,1,1)                          0      290       0
# 1,1,2,2-tetrachloroethane (TETRACHLOROETHANE-1,...         0      386       0
# 1,2,3,4,5,6-hexachlorocyclohexane (HCH)                    0        0       0
# 1,2-dichloroethane (DCE-1,2)                               0   250420  277154
# Aldrin                                                     0        0       0
# ...                                                      ...      ...     ...
# Trichloroethylene (TRI)                                    0   161210   31290
# Trichloromethane                                           0   396673   93000
# Vinyl chloride                                             0   563030  477461
# Xylenes                                                    0        0       0
# Zinc and compounds (as Zn)                              8194  2113823  332110
#
# countryname                                         Switzerland  \
# pollutant
# 1,1,1-trichloroethane (TCE-1,1,1)                             0
# 1,1,2,2-tetrachloroethane (TETRACHLOROETHANE-1,...          109
# 1,2,3,4,5,6-hexachlorocyclohexane (HCH)                       0
# 1,2-dichloroethane (DCE-1,2)                               5889
# Aldrin                                                        0
# ...                                                         ...
# Trichloroethylene (TRI)                                  243450
# Trichloromethane                                           7035
# Vinyl chloride                                                0
# Xylenes                                                       0
# Zinc and compounds (as Zn)                               137844
#
# countryname                                         United Kingdom
# pollutant
# 1,1,1-trichloroethane (TCE-1,1,1)                            46923
# 1,1,2,2-tetrachloroethane (TETRACHLOROETHANE-1,...           22805
# 1,2,3,4,5,6-hexachlorocyclohexane (HCH)                          0
# 1,2-dichloroethane (DCE-1,2)                               3663180
# Aldrin                                                           0
# ...                                                            ...
# Trichloroethylene (TRI)                                    2383010
# Trichloromethane                                            235694
# Vinyl chloride                                              960230
# Xylenes                                                     289110
# Zinc and compounds (as Zn)                                  534517
#
# [68 rows x 32 columns]

# %%
display(df_air_releases_facilities.facilityname.nunique())
df_air_releases_facilities.facilityname.value_counts()
# Out:
# 0
# Series([], Name: count, dtype: int64)
